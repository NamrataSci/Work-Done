# %%
import numpy as np
import pandas as pd
# !pip install pillow
import PIL
from PIL import Image
# Out:
# Requirement already satisfied: pillow in c:\users\acer\anaconda3\lib\site-packages (8.0.1)

# %%
#Open Image
im = Image.open(r"D:\tajmahal.jpg")

# %%
# Show Image
im.show()

# %%
#Image rotate & show
im.rotate(45).show()

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1109 at 0x1BDD9621D30>

# %%
im.size
# Out:
# (1200, 1109)

# %%
im.format
# Out:
# 'JPEG'

# %%
#Resize-thumbnails()
im.thumbnail ((300, 300))
im.show()

# %%
#Converting to grayscale image − convert()
tajmahal_gray = Image.open(r"D:\tajmahal.jpg").convert('L')
tajmahal_gray.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
im = cv2.imread('TajMahal.jpg',cv2.IMREAD_GRAYSCALE)

# %%
# to hide tick values on X and Y axis
plt.xticks([]), plt.yticks([])
plt.plot([200,300,400],[100,200,300],'c', linewidth = 5)
plt.show()
