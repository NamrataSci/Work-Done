# %% [markdown]
# Introduction to Matplotlib

# %%
import matplotlib

# %%
from matplotlib import pyplot as plt

# %%
x=[5,2,9,4,7]

# %%
y=[10,5,8,4,2]

# %%
plt.plot(x,y)

# %%
plt.show()

# %%
import numpy as np
x = np.linspace(0,10,20)
y=x**2

# %%
plt.plot(x,y)

# %%
#Barplot

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.show()

# %%
#Histogram - represents the frequency

# %%
plt.hist(y)
# Out:
# (array([1., 0., 1., 1., 0., 0., 0., 1., 0., 1.]),
#  array([ 2. ,  2.8,  3.6,  4.4,  5.2,  6. ,  6.8,  7.6,  8.4,  9.2, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.show()

# %%
#scatterplot

# %%
plt.scatter(x,y)

# %%
plt.show()

# %%
import matplotlib

# %%
from matplotlib import pyplot as plt

# %%
x=[5,2,9,4,7]

# %%
y=[10,5,8,4,2]

# %%
plt.scatter(x,y)

# %%
plt.title("Scatter Plot")
plt.xlabel("Time(hr)")
plt.ylabel("Position(Km)")
# Out:
# Text(0, 0.5, 'Position(Km)')

# %%
plt.xlabel("Time(hr)")
plt.ylabel("Position(Km)")
# Out:
# Text(0, 0.5, 'Position(Km)')

# %%
plt.scatter(x,y)

# %%
plt.show()

# %%
graph3=plt.scatter(x,y)
plt.xlabel("Time(hr)")
plt.ylabel("Position(Km)")
# Out:
# Text(0, 0.5, 'Position(Km)')

# %%
plt.title("random dist")
plt.xlabel("hr")
plt.ylabel("position")
# Out:
# Text(0, 0.5, 'position')

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
y=np.array([35,25,25,15])

# %%
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x19c75292160>,
#   <matplotlib.patches.Wedge at 0x19c75292640>,
#   <matplotlib.patches.Wedge at 0x19c75292ac0>,
#   <matplotlib.patches.Wedge at 0x19c75292f40>],
#  [Text(0.4993895680663529, 0.9801071672559597, ''),
#   Text(-1.086457168210212, 0.17207795223283895, ''),
#   Text(-0.172077952232839, -1.086457168210212, ''),
#   Text(0.9801071672559598, -0.4993895680663526, '')])

# %%
plt.show()

# %%
mylabels=["Apples","Banana","Cherry","Dates"]

# %%
plt.pie(y,labels=mylabels,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x19c756fd7f0>,
#   <matplotlib.patches.Wedge at 0x19c756fdcd0>,
#   <matplotlib.patches.Wedge at 0x19c7570a190>,
#   <matplotlib.patches.Wedge at 0x19c7570a610>],
#  [Text(-0.9801071672559597, 0.49938956806635293, 'Apples'),
#   Text(-0.172077952232839, -1.086457168210212, 'Banana'),
#   Text(1.086457168210212, -0.17207795223283906, 'Cherry'),
#   Text(0.49938956806635265, 0.9801071672559598, 'Dates')])

# %%
plt.show()

# %%
myexplode=[0.2,0,0,0]

# %%
plt.pie(y,labels=mylabels,explode=myexplode)
# Out:
# ([<matplotlib.patches.Wedge at 0x19c7563eaf0>,
#   <matplotlib.patches.Wedge at 0x19c7563efd0>,
#   <matplotlib.patches.Wedge at 0x19c7564d490>,
#   <matplotlib.patches.Wedge at 0x19c7564d910>],
#  [Text(0.5901876713511442, 1.1583084703934068, 'Apples'),
#   Text(-1.086457168210212, 0.17207795223283895, 'Banana'),
#   Text(-0.172077952232839, -1.086457168210212, 'Cherry'),
#   Text(0.9801071672559598, -0.4993895680663526, 'Dates')])

# %%
plt.show()

# %%
plt.legend(title="Four Fruits:")
# Out:
# No handles with labels found to put in legend.

# %%
x=np.array([0,1,2,3])

# %%
y=np.array([3,8,1,10])

# %%
plt.subplot(1,2,1)
# Out:
# <AxesSubplot:>

# %%
plt.plot(x,y)

# %%
#plot2

# %%
plt.plot(1,2,2)
# Out:
# [<matplotlib.lines.Line2D at 0x19c7561e7f0>,
#  <matplotlib.lines.Line2D at 0x19c7561ec10>]

# %%
plt.plot(x,y)

# %%
#6 plots

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)
x=np.array([0,1,2,3])

# %%
y=np.array([3,8,1,10])

# %%
plt.subplot(2,3,1)
# Out:
# <AxesSubplot:>

# %%
plt.plot(x,y)

# %%
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,3)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,3,4)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,5)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,3,6)
plt.plot(x,y)

plt.show()
